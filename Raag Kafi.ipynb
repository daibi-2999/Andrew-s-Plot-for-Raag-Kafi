# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga Kafi.csv")

# %%
print(df.head())
# Out:
#    Song Name   P(S)=X1  P(r )=X2   P(R)=X3   P(g)=X4  P(G)=X5   P(M)=X6  \
# 0  Raag kafi  0.166667         0  0.090909  0.181818        0  0.136364
#
#    P(m)=X7   P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=12
# 0        0  0.227273        0  0.227273  0.121212        0

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="Yellow")
